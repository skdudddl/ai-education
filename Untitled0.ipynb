# %% [markdown]
# <a href="https://colab.research.google.com/github/skdudddl/ai-education/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout,BatchNormalization,LeakyReLU
from tensorflow.keras.optimizers import Adam

# %%
(x_train,y_train),(x_test,y_test)=ds.cifar10.load_data()
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10)

# %%
cnn=Sequential()
cnn.add(Conv2D(32,(3,3),activation='relu',padding = 'same', kernel_initializer='he_uniform',input_shape=(32,32,3)))
cnn.add(BatchNormalization())
cnn.add(Conv2D(32,(3,3),activation='relu',padding = 'same' ,kernel_initializer='he_uniform'))
cnn.add(BatchNormalization())
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(LeakyReLU())
cnn.add(Dropout(0.25))

cnn.add(Conv2D(64,(3,3),activation='relu',padding = 'same' ,kernel_initializer='he_uniform'))
cnn.add(BatchNormalization())
cnn.add(Conv2D(64,(3,3),activation='relu',padding = 'same',kernel_initializer='he_uniform'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(BatchNormalization())
cnn.add(LeakyReLU())
cnn.add(Dropout(0.3))

cnn.add(Conv2D(96,(3,3),activation='relu',padding = 'same',kernel_initializer='he_uniform'))
cnn.add(BatchNormalization())
cnn.add(Conv2D(96,(3,3),padding = 'same',kernel_initializer='he_uniform'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(BatchNormalization())
cnn.add(LeakyReLU())
cnn.add(Dropout(0.35))

cnn.add(Conv2D(128,(3,3),activation='relu',padding = 'same',kernel_initializer='he_uniform'))
cnn.add(BatchNormalization())
cnn.add(Conv2D(128,(3,3),padding = 'same',kernel_initializer='he_uniform'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(BatchNormalization())
cnn.add(LeakyReLU())
cnn.add(Dropout(0.4))

cnn.add(Flatten())
cnn.add(Dense(units=512,activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(units=10,activation='softmax'))

# %%
cnn.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])
hist=cnn.fit(x_train,y_train,batch_size=64,epochs=150,validation_data=(x_test,y_test),verbose=2)
# Out:
# Epoch 1/150
# 782/782 - 17s - loss: 1.6125 - accuracy: 0.4180 - val_loss: 1.3560 - val_accuracy: 0.5281 - 17s/epoch - 22ms/step
# Epoch 2/150
# 782/782 - 10s - loss: 1.1591 - accuracy: 0.5867 - val_loss: 0.9964 - val_accuracy: 0.6550 - 10s/epoch - 13ms/step
# Epoch 3/150
# 782/782 - 9s - loss: 0.9630 - accuracy: 0.6637 - val_loss: 0.7879 - val_accuracy: 0.7272 - 9s/epoch - 12ms/step
# Epoch 4/150
# 782/782 - 10s - loss: 0.8444 - accuracy: 0.7049 - val_loss: 0.7782 - val_accuracy: 0.7354 - 10s/epoch - 12ms/step
# Epoch 5/150
# 782/782 - 10s - loss: 0.7623 - accuracy: 0.7370 - val_loss: 0.6737 - val_accuracy: 0.7723 - 10s/epoch - 12ms/step
# Epoch 6/150
# 782/782 - 10s - loss: 0.6995 - accuracy: 0.7610 - val_loss: 0.7039 - val_accuracy: 0.7650 - 10s/epoch - 13ms/step
# Epoch 7/150
# 782/782 - 10s - loss: 0.6506 - accuracy: 0.7772 - val_loss: 0.6127 - val_accuracy: 0.7940 - 10s/epoch - 13ms/step
# Epoch 8/150
# ...

# %%
res=cnn.evaluate(x_test,y_test,verbose=0)
print('정확률=',res[1]*100)
# Out:
# 정확률= 87.9800021648407

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy graph')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'])
plt.grid()
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss graph')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'])
plt.grid()
plt.show()
