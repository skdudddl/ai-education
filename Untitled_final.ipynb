# %% [markdown]
# <a href="https://colab.research.google.com/github/skdudddl/ai-education/blob/main/Untitled_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout,BatchNormalization,LeakyReLU
from tensorflow.keras.optimizers import Adam

# %%
(x_train,y_train),(x_test,y_test)=ds.cifar10.load_data()
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10)

# %%
cnn=Sequential()
cnn.add(Conv2D(32,(3,3),activation='relu',padding = 'same', kernel_initializer='he_uniform',input_shape=(32,32,3)))
cnn.add(BatchNormalization())
cnn.add(Dropout(0.25))
cnn.add(Conv2D(32,(3,3),activation='relu',padding = 'same' ,kernel_initializer='he_uniform'))
cnn.add(BatchNormalization())
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(LeakyReLU())
cnn.add(Dropout(0.25))

cnn.add(Conv2D(64,(3,3),activation='relu',padding = 'same' ,kernel_initializer='he_uniform'))
cnn.add(BatchNormalization())
cnn.add(Dropout(0.3))
cnn.add(Conv2D(64,(3,3),activation='relu',padding = 'same',kernel_initializer='he_uniform'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(BatchNormalization())
cnn.add(LeakyReLU())
cnn.add(Dropout(0.3))

cnn.add(Conv2D(128,(3,3),activation='relu',padding = 'same',kernel_initializer='he_uniform'))
cnn.add(BatchNormalization())
cnn.add(Dropout(0.35))
cnn.add(Conv2D(128,(3,3),padding = 'same',kernel_initializer='he_uniform'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(BatchNormalization())
cnn.add(LeakyReLU())
cnn.add(Dropout(0.35))

cnn.add(Conv2D(256,(3,3),activation='relu',padding = 'same',kernel_initializer='he_uniform'))
cnn.add(BatchNormalization())
cnn.add(Dropout(0.4))
cnn.add(Conv2D(256,(3,3),padding = 'same',kernel_initializer='he_uniform'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(BatchNormalization())
cnn.add(LeakyReLU())
cnn.add(Dropout(0.4))

cnn.add(Conv2D(512,(3,3),activation='relu',padding = 'same',kernel_initializer='he_uniform'))
cnn.add(BatchNormalization())
cnn.add(Dropout(0.45))
cnn.add(Conv2D(512,(3,3),padding = 'same',kernel_initializer='he_uniform'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(BatchNormalization())
cnn.add(LeakyReLU())
cnn.add(Dropout(0.45))

cnn.add(Flatten())
cnn.add(Dense(units=512,activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(units=10,activation='softmax'))

# %%
cnn.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])
hist=cnn.fit(x_train,y_train,batch_size=128,epochs=150,validation_data=(x_test,y_test),verbose=2)
# Out:
# Epoch 1/150
# 391/391 - 22s - loss: 1.9893 - accuracy: 0.2633 - val_loss: 3.5323 - val_accuracy: 0.1585 - 22s/epoch - 58ms/step
# Epoch 2/150
# 391/391 - 12s - loss: 1.5229 - accuracy: 0.4368 - val_loss: 1.3849 - val_accuracy: 0.5066 - 12s/epoch - 32ms/step
# Epoch 3/150
# 391/391 - 12s - loss: 1.3106 - accuracy: 0.5276 - val_loss: 1.2424 - val_accuracy: 0.5736 - 12s/epoch - 32ms/step
# Epoch 4/150
# 391/391 - 12s - loss: 1.1572 - accuracy: 0.5900 - val_loss: 1.3277 - val_accuracy: 0.5799 - 12s/epoch - 31ms/step
# Epoch 5/150
# 391/391 - 12s - loss: 1.0417 - accuracy: 0.6330 - val_loss: 1.0323 - val_accuracy: 0.6585 - 12s/epoch - 31ms/step
# Epoch 6/150
# 391/391 - 12s - loss: 0.9422 - accuracy: 0.6714 - val_loss: 0.9102 - val_accuracy: 0.6830 - 12s/epoch - 32ms/step
# Epoch 7/150
# 391/391 - 12s - loss: 0.8675 - accuracy: 0.7005 - val_loss: 1.0325 - val_accuracy: 0.6666 - 12s/epoch - 31ms/step
# Epoch 8/150
# ...

# %%
res=cnn.evaluate(x_test,y_test,verbose=0)
print('정확률=',res[1]*100)
# Out:
# 정확률= 88.7000024318695

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy graph')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'])
plt.grid()
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss graph')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'])
plt.grid()
plt.show()
